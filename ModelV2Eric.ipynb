# %%
#imports
import os
import random
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import mixed_precision

# %%
# 2. Configuration
mixed_precision.set_global_policy('mixed_float16')

DATA_DIR = '/content/drive/MyDrive/birdclef-2025/train_audio'
CSV_PATH = '/content/train.xlsx'
SAVE_DIR = '/content/drive/MyDrive/birdclef-2025/spectrograms'  # <-- Save spectrograms here
SAMPLE_RATE = 32000
DURATION = 5
N_MELS = 128
SEED = 42
MODEL_SAVE_PATH = 'best_model.keras'

os.makedirs(SAVE_DIR, exist_ok=True)

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# 3. Load Metadata and Filter Species
df = pd.read_excel(CSV_PATH)
species_counts = df['primary_label'].value_counts()
eligible_species = species_counts.head(10).index  # Limit to top 50 most common species
df = df[df['primary_label'].isin(eligible_species)]

# %%
# 4. Sample a Subset
species_list = df['primary_label'].unique().tolist()
species_to_idx = {species: idx for idx, species in enumerate(species_list)}
idx_to_species = {idx: df[df['primary_label'] == species]['common_name'].values[0] for species, idx in species_to_idx.items()}
df['label_idx'] = df['primary_label'].map(species_to_idx)

# Bootstrapping
bootstrapped_samples = []
n_samples_per_species = 500
for label in df['primary_label'].unique():
    species_files = df[df['primary_label'] == label]
    resampled_species = species_files.sample(n=n_samples_per_species, replace=True, random_state=SEED)
    bootstrapped_samples.append(resampled_species)
bootstrapped_files = pd.concat(bootstrapped_samples).reset_index(drop=True)

# %%
#6. Audio Preprocessing
def load_audio(path, duration=DURATION, sr=SAMPLE_RATE):
    y, _ = librosa.load(path, sr=sr)
    if len(y) < sr * duration:
        padding = sr * duration - len(y)
        y = np.pad(y, (0, padding))
    else:
        y = y[:sr * duration]
    return y

def audio_to_melspectrogram(y, sr=SAMPLE_RATE, n_mels=N_MELS):
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    return mel_db

def add_noise(y, noise_factor=0.005):
    noise = np.random.randn(len(y))
    augmented_y = y + noise_factor * noise
    return np.clip(augmented_y, -1.0, 1.0)

def time_shift(y, shift_max=0.2):
    shift = np.random.randint(SAMPLE_RATE * DURATION * shift_max)
    direction = np.random.choice([-1, 1])
    shift = direction * shift
    augmented_y = np.roll(y, shift)
    return augmented_y

def spec_augment(mel, time_mask_width=10, freq_mask_width=8):
    mel = mel.copy()
    num_mel_channels, num_time_steps = mel.shape

    # Time mask
    t = np.random.randint(0, time_mask_width)
    t0 = np.random.randint(0, num_time_steps - t)
    mel[:, t0:t0 + t] = 0

    # Frequency mask
    f = np.random.randint(0, freq_mask_width)
    f0 = np.random.randint(0, num_mel_channels - f)
    mel[f0:f0 + f, :] = 0

    return mel

# %%
# 7. Dataset Preparation
X = []
y = []

print("\nLoading audio and generating/loading spectrograms with augmentation...")
for i, row in tqdm(bootstrapped_files.iterrows(), total=len(bootstrapped_files)):
    filename_base = row['filename'].replace('/', '_').replace('.ogg', '')
    mel_path = os.path.join(SAVE_DIR, filename_base + '.npy')

    if os.path.exists(mel_path):
        mel = np.load(mel_path)
    else:
        file_path = os.path.join(DATA_DIR, row['filename'])
        if os.path.exists(file_path):
            y_audio = load_audio(file_path)
            if random.random() < 0.5:
                y_audio = add_noise(y_audio)
            if random.random() < 0.5:
                y_audio = time_shift(y_audio)
            mel = audio_to_melspectrogram(y_audio)
            np.save(mel_path, mel)

    if random.random() < 0.5:
        mel = spec_augment(mel)

    X.append(mel)
    y.append(row['label_idx'])

X = np.array(X)
y = np.array(y)

X = X[..., np.newaxis]
# Out:
# Loading audio and generating/loading spectrograms with augmentation...
# 100%|██████████| 5000/5000 [17:46<00:00,  4.69it/s]

# %%
# 9. CNN Model
def create_cnn(input_shape, num_classes):
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.GlobalAveragePooling2D(),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

model = create_cnn(X_train.shape[1:], len(species_list))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 8. Stratified K-Fold Cross Validation
from sklearn.model_selection import StratifiedKFold

NUM_FOLDS = 5
kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state=SEED)
fold_accuracies = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"\n--- Fold {fold + 1} ---")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

    val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
    val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

    model = create_cnn(X_train.shape[1:], len(species_list))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
        ModelCheckpoint(f'model_fold{fold+1}.keras', monitor='val_loss', save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
    ]

    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=50,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluation per fold
y_pred = model.predict(val_dataset)
y_pred_classes = np.argmax(y_pred, axis=1)

print("\nFold Classification Report:\n")
print(classification_report(y_val, y_pred_classes, target_names=[idx_to_species[idx] for idx in range(len(species_list))]))

fold_acc = np.mean(y_pred_classes == y_val)
fold_accuracies.append(fold_acc)
print(f"Fold {fold+1} Accuracy: {fold_acc:.4f}")

# 9. Final Results
print("\nCross-Validation Results:")
print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Accuracy per fold: {fold_accuracies}")
# Out:
# --- Fold 1 ---
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.1225 - loss: 4.8443 - val_accuracy: 0.0980 - val_loss: 2.7622 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1226 - loss: 2.3543 - val_accuracy: 0.1050 - val_loss: 2.3083 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0309 - loss: 2.3589 - val_accuracy: 0.1000 - val_loss: 2.3039 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0279 - loss: 2.3330 - val_accuracy: 0.1010 - val_loss: 2.3058 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1342 - loss: 2.1782 - val_accuracy: 0.1000 - val_loss: 2.6761 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1966 - loss: 2.1428 - val_accuracy: 0.1000 - val_loss: 2.6158 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0934 - loss: 2.4982 - val_accuracy: 0.1000 - val_loss: 2.3223 - learning_rate: 5.0000e-04
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0391 - loss: 2.3929 - val_accuracy: 0.0990 - val_loss: 2.3046 - learning_rate: 5.0000e-04
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0320 - loss: 2.3439 - val_accuracy: 0.1000 - val_loss: 2.3038 - learning_rate: 5.0000e-04
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0527 - loss: 2.3380 - val_accuracy: 0.1000 - val_loss: 2.3035 - learning_rate: 2.5000e-04
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0509 - loss: 2.3343 - val_accuracy: 0.1000 - val_loss: 2.3034 - learning_rate: 2.5000e-04
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0495 - loss: 2.3318 - val_accuracy: 0.1000 - val_loss: 2.3034 - learning_rate: 2.5000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0533 - loss: 2.3310 - val_accuracy: 0.1000 - val_loss: 2.3055 - learning_rate: 2.5000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0534 - loss: 2.3389 - val_accuracy: 0.0990 - val_loss: 2.3031 - learning_rate: 2.5000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0477 - loss: 2.3287 - val_accuracy: 0.1000 - val_loss: 2.3030 - learning_rate: 2.5000e-04
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0466 - loss: 2.3285 - val_accuracy: 0.0990 - val_loss: 2.3029 - learning_rate: 2.5000e-04
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0457 - loss: 2.3279 - val_accuracy: 0.0990 - val_loss: 2.3028 - learning_rate: 2.5000e-04
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0473 - loss: 2.3274 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 2.5000e-04
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0466 - loss: 2.3252 - val_accuracy: 0.0960 - val_loss: 2.3035 - learning_rate: 2.5000e-04
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0708 - loss: 2.2758 - val_accuracy: 0.0970 - val_loss: 2.3030 - learning_rate: 2.5000e-04
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0465 - loss: 2.3303 - val_accuracy: 0.0990 - val_loss: 2.3037 - learning_rate: 2.5000e-04
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0464 - loss: 2.3294 - val_accuracy: 0.0970 - val_loss: 2.3026 - learning_rate: 1.2500e-04
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0495 - loss: 2.3267 - val_accuracy: 0.0960 - val_loss: 2.3025 - learning_rate: 1.2500e-04
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0483 - loss: 2.3255 - val_accuracy: 0.0960 - val_loss: 2.3024 - learning_rate: 1.2500e-04
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0499 - loss: 2.3252 - val_accuracy: 0.0960 - val_loss: 2.3023 - learning_rate: 1.2500e-04
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0488 - loss: 2.3246 - val_accuracy: 0.0970 - val_loss: 2.3023 - learning_rate: 1.2500e-04
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0474 - loss: 2.3240 - val_accuracy: 0.0970 - val_loss: 2.3022 - learning_rate: 1.2500e-04
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0478 - loss: 2.3230 - val_accuracy: 0.0970 - val_loss: 2.3022 - learning_rate: 1.2500e-04
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0478 - loss: 2.3234 - val_accuracy: 0.0960 - val_loss: 2.3021 - learning_rate: 1.2500e-04
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0486 - loss: 2.3228 - val_accuracy: 0.0970 - val_loss: 2.3021 - learning_rate: 1.2500e-04
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0496 - loss: 2.3232 - val_accuracy: 0.0970 - val_loss: 2.3019 - learning_rate: 1.2500e-04
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0471 - loss: 2.3221 - val_accuracy: 0.0960 - val_loss: 2.3019 - learning_rate: 1.2500e-04
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0459 - loss: 2.3217 - val_accuracy: 0.0950 - val_loss: 2.3017 - learning_rate: 1.2500e-04
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0470 - loss: 2.3213 - val_accuracy: 0.0950 - val_loss: 2.3017 - learning_rate: 1.2500e-04
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0315 - loss: 2.3217 - val_accuracy: 0.0970 - val_loss: 2.3018 - learning_rate: 1.2500e-04
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0480 - loss: 2.3222 - val_accuracy: 0.0970 - val_loss: 2.3016 - learning_rate: 1.2500e-04
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0456 - loss: 2.3204 - val_accuracy: 0.0970 - val_loss: 2.3016 - learning_rate: 1.2500e-04
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0442 - loss: 2.3201 - val_accuracy: 0.0960 - val_loss: 2.3015 - learning_rate: 1.2500e-04
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0452 - loss: 2.3198 - val_accuracy: 0.0930 - val_loss: 2.3014 - learning_rate: 1.2500e-04
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.0445 - loss: 2.3195 - val_accuracy: 0.0940 - val_loss: 2.3014 - learning_rate: 1.2500e-04
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0463 - loss: 2.3182 - val_accuracy: 0.0940 - val_loss: 2.3014 - learning_rate: 1.2500e-04
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0442 - loss: 2.3187 - val_accuracy: 0.0960 - val_loss: 2.3012 - learning_rate: 6.2500e-05
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0463 - loss: 2.3182 - val_accuracy: 0.0940 - val_loss: 2.3012 - learning_rate: 6.2500e-05
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0453 - loss: 2.3168 - val_accuracy: 0.0940 - val_loss: 2.3011 - learning_rate: 6.2500e-05
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0442 - loss: 2.3173 - val_accuracy: 0.0930 - val_loss: 2.3010 - learning_rate: 6.2500e-05
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0449 - loss: 2.3170 - val_accuracy: 0.0940 - val_loss: 2.3010 - learning_rate: 6.2500e-05
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0469 - loss: 2.3168 - val_accuracy: 0.0940 - val_loss: 2.3010 - learning_rate: 6.2500e-05
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0488 - loss: 2.3175 - val_accuracy: 0.0940 - val_loss: 2.3009 - learning_rate: 6.2500e-05
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0488 - loss: 2.3160 - val_accuracy: 0.0950 - val_loss: 2.3009 - learning_rate: 6.2500e-05
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0475 - loss: 2.3161 - val_accuracy: 0.0950 - val_loss: 2.3008 - learning_rate: 6.2500e-05
#
# --- Fold 2 ---
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.2627 - loss: 2.8392 - val_accuracy: 0.1000 - val_loss: 2.7211 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1824 - loss: 2.2763 - val_accuracy: 0.1000 - val_loss: 2.6812 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.1025 - loss: 2.4025 - val_accuracy: 0.1000 - val_loss: 2.6383 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0931 - loss: 2.3830 - val_accuracy: 0.0980 - val_loss: 2.3031 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0996 - loss: 2.2992 - val_accuracy: 0.0940 - val_loss: 2.3034 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1244 - loss: 2.1953 - val_accuracy: 0.1000 - val_loss: 2.3063 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0246 - loss: 2.3419 - val_accuracy: 0.1010 - val_loss: 2.3029 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0369 - loss: 2.3162 - val_accuracy: 0.1010 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0379 - loss: 2.3129 - val_accuracy: 0.1010 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0461 - loss: 2.3126 - val_accuracy: 0.1120 - val_loss: 2.3027 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0559 - loss: 2.3097 - val_accuracy: 0.1110 - val_loss: 2.3029 - learning_rate: 0.0010
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0399 - loss: 2.3089 - val_accuracy: 0.1080 - val_loss: 2.3029 - learning_rate: 5.0000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0403 - loss: 2.3087 - val_accuracy: 0.0980 - val_loss: 2.3029 - learning_rate: 5.0000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0327 - loss: 2.3093 - val_accuracy: 0.0990 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0369 - loss: 2.3093 - val_accuracy: 0.1060 - val_loss: 2.3028 - learning_rate: 2.5000e-04
#
# --- Fold 3 ---
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.1913 - loss: 2.9780 - val_accuracy: 0.1000 - val_loss: 2.6947 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.1639 - loss: 2.3614 - val_accuracy: 0.1000 - val_loss: 2.5985 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0585 - loss: 2.4135 - val_accuracy: 0.1000 - val_loss: 2.3032 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0283 - loss: 2.3257 - val_accuracy: 0.1000 - val_loss: 2.3027 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0419 - loss: 2.3140 - val_accuracy: 0.0990 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0470 - loss: 2.3132 - val_accuracy: 0.0920 - val_loss: 2.3025 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0471 - loss: 2.3124 - val_accuracy: 0.0980 - val_loss: 2.3025 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0449 - loss: 2.3131 - val_accuracy: 0.1060 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0528 - loss: 2.3129 - val_accuracy: 0.1040 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0313 - loss: 2.3127 - val_accuracy: 0.1050 - val_loss: 2.3026 - learning_rate: 5.0000e-04
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0407 - loss: 2.3127 - val_accuracy: 0.1100 - val_loss: 2.3026 - learning_rate: 5.0000e-04
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0339 - loss: 2.3125 - val_accuracy: 0.1090 - val_loss: 2.3025 - learning_rate: 5.0000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0383 - loss: 2.3118 - val_accuracy: 0.1090 - val_loss: 2.3025 - learning_rate: 2.5000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0409 - loss: 2.3117 - val_accuracy: 0.1100 - val_loss: 2.3025 - learning_rate: 2.5000e-04
#
# --- Fold 4 ---
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.1617 - loss: 3.3670 - val_accuracy: 0.1000 - val_loss: 2.5991 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.1644 - loss: 2.3520 - val_accuracy: 0.1000 - val_loss: 2.6689 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1390 - loss: 2.4014 - val_accuracy: 0.1000 - val_loss: 2.7778 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0871 - loss: 2.3944 - val_accuracy: 0.1000 - val_loss: 2.5861 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1127 - loss: 2.3687 - val_accuracy: 0.1000 - val_loss: 2.3041 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1857 - loss: 2.2804 - val_accuracy: 0.1000 - val_loss: 2.3036 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.1871 - loss: 2.2861 - val_accuracy: 0.0900 - val_loss: 2.3028 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.1288 - loss: 2.2951 - val_accuracy: 0.1030 - val_loss: 2.3029 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1988 - loss: 2.2960 - val_accuracy: 0.1000 - val_loss: 2.3028 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1638 - loss: 2.2989 - val_accuracy: 0.0910 - val_loss: 2.3028 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1553 - loss: 2.3005 - val_accuracy: 0.0910 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.1500 - loss: 2.3007 - val_accuracy: 0.0870 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.1317 - loss: 2.3013 - val_accuracy: 0.0930 - val_loss: 2.3027 - learning_rate: 5.0000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.1237 - loss: 2.3015 - val_accuracy: 0.0940 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1232 - loss: 2.3015 - val_accuracy: 0.0900 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1231 - loss: 2.3018 - val_accuracy: 0.0940 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1101 - loss: 2.3016 - val_accuracy: 0.0980 - val_loss: 2.3027 - learning_rate: 1.2500e-04
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.1004 - loss: 2.3017 - val_accuracy: 0.0990 - val_loss: 2.3027 - learning_rate: 1.2500e-04
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.1001 - loss: 2.3016 - val_accuracy: 0.1010 - val_loss: 2.3027 - learning_rate: 1.2500e-04
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0857 - loss: 2.3014 - val_accuracy: 0.1070 - val_loss: 2.3027 - learning_rate: 6.2500e-05
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0873 - loss: 2.3016 - val_accuracy: 0.1010 - val_loss: 2.3027 - learning_rate: 6.2500e-05
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0986 - loss: 2.3013 - val_accuracy: 0.1010 - val_loss: 2.3027 - learning_rate: 6.2500e-05
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0872 - loss: 2.3013 - val_accuracy: 0.1010 - val_loss: 2.3027 - learning_rate: 6.2500e-05
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0928 - loss: 2.3014 - val_accuracy: 0.1070 - val_loss: 2.3027 - learning_rate: 3.1250e-05
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0890 - loss: 2.3013 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 3.1250e-05
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0863 - loss: 2.3013 - val_accuracy: 0.1090 - val_loss: 2.3026 - learning_rate: 3.1250e-05
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0910 - loss: 2.3013 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 1.5625e-05
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0924 - loss: 2.3012 - val_accuracy: 0.1070 - val_loss: 2.3026 - learning_rate: 1.5625e-05
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0984 - loss: 2.3008 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 1.5625e-05
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0903 - loss: 2.3011 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 7.8125e-06
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0946 - loss: 2.3009 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 7.8125e-06
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0981 - loss: 2.3009 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 7.8125e-06
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.0991 - loss: 2.3008 - val_accuracy: 0.1060 - val_loss: 2.3026 - learning_rate: 7.8125e-06
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0988 - loss: 2.3010 - val_accuracy: 0.1060 - val_loss: 2.3026 - learning_rate: 3.9063e-06
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1041 - loss: 2.3007 - val_accuracy: 0.1080 - val_loss: 2.3026 - learning_rate: 3.9063e-06
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0981 - loss: 2.3011 - val_accuracy: 0.1090 - val_loss: 2.3026 - learning_rate: 3.9063e-06
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0917 - loss: 2.3011 - val_accuracy: 0.1090 - val_loss: 2.3026 - learning_rate: 1.9531e-06
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0951 - loss: 2.3010 - val_accuracy: 0.1090 - val_loss: 2.3026 - learning_rate: 1.9531e-06
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.0990 - loss: 2.3008 - val_accuracy: 0.1090 - val_loss: 2.3025 - learning_rate: 1.9531e-06
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0959 - loss: 2.3010 - val_accuracy: 0.1090 - val_loss: 2.3025 - learning_rate: 9.7656e-07
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.0978 - loss: 2.3008 - val_accuracy: 0.1120 - val_loss: 2.3025 - learning_rate: 9.7656e-07
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1013 - loss: 2.3008 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 9.7656e-07
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0966 - loss: 2.3011 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 4.8828e-07
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.1075 - loss: 2.3005 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 4.8828e-07
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1008 - loss: 2.3010 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 4.8828e-07
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1015 - loss: 2.3010 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 2.4414e-07
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.1029 - loss: 2.3009 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 2.4414e-07
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0977 - loss: 2.3008 - val_accuracy: 0.1110 - val_loss: 2.3025 - learning_rate: 2.4414e-07
#
# --- Fold 5 ---
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.1701 - loss: 2.7272 - val_accuracy: 0.1000 - val_loss: 2.4550 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1530 - loss: 2.2406 - val_accuracy: 0.0970 - val_loss: 2.3084 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1635 - loss: 2.2250 - val_accuracy: 0.1000 - val_loss: 2.5654 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1377 - loss: 2.2848 - val_accuracy: 0.1130 - val_loss: 2.3217 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0161 - loss: 2.3779 - val_accuracy: 0.1000 - val_loss: 2.3069 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0163 - loss: 2.3529 - val_accuracy: 0.1000 - val_loss: 2.3052 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0176 - loss: 2.3420 - val_accuracy: 0.1000 - val_loss: 2.3048 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0169 - loss: 2.3395 - val_accuracy: 0.1000 - val_loss: 2.3041 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0112 - loss: 2.3324 - val_accuracy: 0.1000 - val_loss: 2.7164 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0239 - loss: 2.4226 - val_accuracy: 0.1000 - val_loss: 2.3031 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0126 - loss: 2.3226 - val_accuracy: 0.0990 - val_loss: 2.3033 - learning_rate: 0.0010
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0131 - loss: 2.3252 - val_accuracy: 0.1010 - val_loss: 2.3030 - learning_rate: 0.0010
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0129 - loss: 2.3218 - val_accuracy: 0.1050 - val_loss: 2.3030 - learning_rate: 0.0010
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0186 - loss: 2.3217 - val_accuracy: 0.1020 - val_loss: 2.3030 - learning_rate: 5.0000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0199 - loss: 2.3210 - val_accuracy: 0.1020 - val_loss: 2.3030 - learning_rate: 5.0000e-04
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0174 - loss: 2.3205 - val_accuracy: 0.1000 - val_loss: 2.3029 - learning_rate: 5.0000e-04
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0188 - loss: 2.3199 - val_accuracy: 0.1030 - val_loss: 2.3029 - learning_rate: 5.0000e-04
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0186 - loss: 2.3191 - val_accuracy: 0.0990 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0180 - loss: 2.3188 - val_accuracy: 0.0980 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.0182 - loss: 2.3184 - val_accuracy: 0.0990 - val_loss: 2.3028 - learning_rate: 5.0000e-04
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0176 - loss: 2.3180 - val_accuracy: 0.0990 - val_loss: 2.3027 - learning_rate: 5.0000e-04
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0199 - loss: 2.3179 - val_accuracy: 0.1010 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0203 - loss: 2.3179 - val_accuracy: 0.1040 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0210 - loss: 2.3174 - val_accuracy: 0.1020 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0206 - loss: 2.3175 - val_accuracy: 0.1040 - val_loss: 2.3027 - learning_rate: 2.5000e-04
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0215 - loss: 2.3172 - val_accuracy: 0.1040 - val_loss: 2.3027 - learning_rate: 1.2500e-04
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0227 - loss: 2.3172 - val_accuracy: 0.1050 - val_loss: 2.3026 - learning_rate: 1.2500e-04
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0224 - loss: 2.3170 - val_accuracy: 0.1040 - val_loss: 2.3026 - learning_rate: 1.2500e-04
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0223 - loss: 2.3170 - val_accuracy: 0.1040 - val_loss: 2.3026 - learning_rate: 1.2500e-04
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0216 - loss: 2.3171 - val_accuracy: 0.1050 - val_loss: 2.3026 - learning_rate: 1.2500e-04
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0222 - loss: 2.3168 - val_accuracy: 0.1050 - val_loss: 2.3026 - learning_rate: 6.2500e-05
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0222 - loss: 2.3169 - val_accuracy: 0.1050 - val_loss: 2.3026 - learning_rate: 6.2500e-05
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0224 - loss: 2.3169 - val_accuracy: 0.1040 - val_loss: 2.3026 - learning_rate: 6.2500e-05
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0221 - loss: 2.3172 - val_accuracy: 0.1040 - val_loss: 2.3026 - learning_rate: 3.1250e-05
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0218 - loss: 2.3166 - val_accuracy: 0.1040 - val_loss: 2.3025 - learning_rate: 3.1250e-05
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0238 - loss: 2.3167 - val_accuracy: 0.1030 - val_loss: 2.3025 - learning_rate: 3.1250e-05
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0233 - loss: 2.3168 - val_accuracy: 0.1030 - val_loss: 2.3025 - learning_rate: 1.5625e-05
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0224 - loss: 2.3165 - val_accuracy: 0.1030 - val_loss: 2.3025 - learning_rate: 1.5625e-05
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0240 - loss: 2.3161 - val_accuracy: 0.1030 - val_loss: 2.3025 - learning_rate: 1.5625e-05
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0233 - loss: 2.3167 - val_accuracy: 0.1030 - val_loss: 2.3025 - learning_rate: 1.5625e-05
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0236 - loss: 2.3170 - val_accuracy: 0.1020 - val_loss: 2.3025 - learning_rate: 7.8125e-06
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0241 - loss: 2.3165 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 7.8125e-06
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0229 - loss: 2.3167 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 7.8125e-06
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.0233 - loss: 2.3162 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0226 - loss: 2.3162 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.0244 - loss: 2.3166 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0233 - loss: 2.3166 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0240 - loss: 2.3164 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0232 - loss: 2.3166 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 3.9063e-06
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0227 - loss: 2.3166 - val_accuracy: 0.1020 - val_loss: 2.3024 - learning_rate: 1.9531e-06
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# Fold Classification Report:
#
#                           precision    recall  f1-score   support
#
#               Bananaquit       0.00      0.00      0.00       100
#   Boat-billed Flycatcher       0.00      0.00      0.00       100
#          Common Pauraque       0.00      0.00      0.00       100
#           Great Kiskadee       0.00      0.00      0.00       100
#            Roadside Hawk       0.00      0.00      0.00       100
#        Social Flycatcher       0.08      0.01      0.02       100
#        Tropical Kingbird       0.00      0.00      0.00       100
# White-breasted Wood-Wren       0.00      0.00      0.00       100
#        White-tipped Dove       0.11      0.44      0.17       100
#  Yellow-olive Flycatcher       0.10      0.57      0.17       100
#
#                 accuracy                           0.10      1000
#                macro avg       0.03      0.10      0.04      1000
#             weighted avg       0.03      0.10      0.04      1000
#
# Fold 5 Accuracy: 0.1020
#
# Cross-Validation Results:
# Mean Accuracy: 0.1020
# Accuracy per fold: [np.float64(0.102)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def generate_grad_cam(model, img_array, pred_index=None):
    grad_model = tf.keras.models.Model([
        model.inputs], [model.get_layer(index=-3).output, model.output])

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_grad_cam(X_val, y_val, model, idx_to_species, num_samples=5):
    indices = random.sample(range(len(X_val)), num_samples)
    for idx in indices:
        img = X_val[idx]
        label = y_val[idx]

        img_array = np.expand_dims(img, axis=0)
        heatmap = generate_grad_cam(model, img_array)

        plt.figure(figsize=(10, 4))
        librosa.display.specshow(img.squeeze(), sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
        plt.imshow(heatmap, alpha=0.5, cmap='jet', extent=(0, img.shape[1], 0, img.shape[0]), aspect='auto')
        plt.title(f"Grad-CAM for True Label: {idx_to_species[label]}")
        plt.colorbar()
        plt.show()

print("\nGenerating Grad-CAM visualizations...")
display_grad_cam(X_val, y_val, model, idx_to_species)


# 13. Binary Confusion Matrix per Species (NEW)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def binary_confusion_matrix(species_idx, y_true, y_pred, idx_to_species):
    y_true_binary = (y_true == species_idx).astype(int)
    y_pred_binary = (y_pred == species_idx).astype(int)
    cm = confusion_matrix(y_true_binary, y_pred_binary)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Other', idx_to_species[species_idx]])
    disp.plot(cmap='Blues')
    plt.title(f'Binary Confusion Matrix: {idx_to_species[species_idx]} vs Rest')
    plt.show()

# Example usage:
# binary_confusion_matrix(species_idx=0, y_true=y_val, y_pred=y_pred_classes, idx_to_species=idx_to_species)

# %%
# 14. Inference Function
def predict_species(file_path, model, species_list):
    y_audio = load_audio(file_path)
    mel = audio_to_melspectrogram(y_audio)
    mel = mel[np.newaxis, ..., np.newaxis]
    preds = model.predict(mel)[0]
    top_indices = preds.argsort()[-5:][::-1]
    top_species = [(species_list[i], preds[i]) for i in top_indices]
    return top_species

# Example:
# file_path = '/path/to/new/audio.ogg'
# predictions = predict_species(file_path, model, species_list)
# print(predictions)
